# %%
import numpy as np
import pandas as pd

# %%
#Load Data 
df = pd.read_csv("cyberCrimeType_and_OnlineFraud.csv")
df
# Out:
#         TransactionID            Timestamp  TransactionAmount TransactionType  \
# 0               25696  2025-06-28 09:32:26             648.24        Purchase
# 1                2026  2025-06-24 21:21:31             631.93           Login
# 2                4659  2025-06-24 08:35:19            3478.68        Purchase
# 3               84171  2025-05-29 08:28:12            2156.50        Purchase
# 4               60840  2025-05-15 22:13:03             563.32        Recharge
# ...               ...                  ...                ...             ...
# 100995          22515  2025-05-29 22:40:43             692.02      Withdrawal
# 100996          23804  2025-06-22 20:50:13            3114.68           Login
# 100997          77701  2025-07-13 07:18:10            1067.32        Purchase
# 100998          24858  2025-06-18 06:06:49            1026.73        Recharge
# 100999          21695  2025-06-07 01:45:53             833.93           Login
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101000 entries, 0 to 100999
# Data columns (total 24 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   TransactionID              101000 non-null  int64
#  1   Timestamp                  101000 non-null  object
#  2   TransactionAmount          98977 non-null   float64
#  3   TransactionType            101000 non-null  object
#  4   AccountAgeDays             101000 non-null  int64
#  5   PreviousFraudCount         101000 non-null  int64
#  6   LoginFrequencyLast7Days    101000 non-null  int64
#  7   AvgTransactionAmount7Days  101000 non-null  float64
#  8   DeviceType                 98980 non-null   object
#  9   VPN_Used                   101000 non-null  bool
#  10  MultipleDeviceUse          101000 non-null  bool
#  11  City                       101000 non-null  object
#  12  IsHighRiskCountry          101000 non-null  bool
# ...

# %%
df.isnull().sum()
# Out:
# TransactionID                   0
# Timestamp                       0
# TransactionAmount            2023
# TransactionType                 0
# AccountAgeDays                  0
# PreviousFraudCount              0
# LoginFrequencyLast7Days         0
# AvgTransactionAmount7Days       0
# DeviceType                   2020
# VPN_Used                        0
# MultipleDeviceUse               0
# City                            0
# IsHighRiskCountry               0
# GeoMismatch                     0
# CrimeType                       0
# FraudFlag                       0
# TransactionHour                 0
# IsWeekend                       0
# SuspiciousAmount                0
# DeviceRiskLevel                 0
# RiskScore                    2025
# FraudCategory                   0
# ManualReviewRequired            0
# OnlineFraudType                 0
# dtype: int64

# %%
df['TransactionAmount'] = df['TransactionAmount'].fillna(df['TransactionAmount'].mean())

# %%
df['DeviceType']=df['DeviceType'].fillna("Unknown")

# %%
df['RiskScore']=df['RiskScore'].fillna(df['RiskScore'].mean())

# %%
df.isnull().sum()
# Out:
# TransactionID                0
# Timestamp                    0
# TransactionAmount            0
# TransactionType              0
# AccountAgeDays               0
# PreviousFraudCount           0
# LoginFrequencyLast7Days      0
# AvgTransactionAmount7Days    0
# DeviceType                   0
# VPN_Used                     0
# MultipleDeviceUse            0
# City                         0
# IsHighRiskCountry            0
# GeoMismatch                  0
# CrimeType                    0
# FraudFlag                    0
# TransactionHour              0
# IsWeekend                    0
# SuspiciousAmount             0
# DeviceRiskLevel              0
# RiskScore                    0
# FraudCategory                0
# ManualReviewRequired         0
# OnlineFraudType              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 144

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.to_csv("Cleaned_Cybercrime_New.csv")
